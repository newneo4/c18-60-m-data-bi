# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importamos el dataset
df = pd.read_csv("/content/df_final.csv")
df
# Out:
#                    ID  Session_Activity_Count  No_Items_Added_InCart  \
# 0        Session_ID_0                1.609438               0.693147
# 1        Session_ID_1                3.663562               0.000000
# 2        Session_ID_2                2.197225               1.791759
# 3        Session_ID_3                1.945910               0.000000
# 4        Session_ID_4                3.465736               2.708050
# ...               ...                     ...                    ...
# 4279  Session_ID_4279                3.178054               1.791759
# 4280  Session_ID_4280                2.079442               1.098612
# 4281  Session_ID_4281                1.609438               0.693147
# 4282  Session_ID_4282                2.197225               1.386294
# 4283  Session_ID_4283                3.465736               1.609438
#
#       No_Items_Removed_FromCart  No_Cart_Viewed  No_Checkout_Confirmed  \
# ...

# %%
#contamos los valores que hay en Cart_Abandoned
df.Cart_Abandoned.value_counts()
# Out:
# Cart_Abandoned
# 1    3668
# 0     616
# Name: count, dtype: int64

# %%
#Observamos la cantidad de variables
features = df.columns[:-1].tolist()
features
# Out:
# ['ID',
#  'Session_Activity_Count',
#  'No_Items_Added_InCart',
#  'No_Items_Removed_FromCart',
#  'No_Cart_Viewed',
#  'No_Checkout_Confirmed',
#  'No_Checkout_Initiated ',
#  'No_Cart_Items_Viewed',
#  'No_Customer_Login',
#  'No_Page_Viewed',
#  'Is_Product_Details_viewed',
#  'Customer_Segment_Type']

# %%
#Eliminar el id que no es necesario para los modelos de machine learning
df = df.drop("ID",axis = 1)
df
# Out:
#       Session_Activity_Count  No_Items_Added_InCart  \
# 0                   1.609438               0.693147
# 1                   3.663562               0.000000
# 2                   2.197225               1.791759
# 3                   1.945910               0.000000
# 4                   3.465736               2.708050
# ...                      ...                    ...
# 4279                3.178054               1.791759
# 4280                2.079442               1.098612
# 4281                1.609438               0.693147
# 4282                2.197225               1.386294
# 4283                3.465736               1.609438
#
#       No_Items_Removed_FromCart  No_Cart_Viewed  No_Checkout_Confirmed  \
# 0                      0.000000        0.000000               0.000000
# 1                      0.000000        1.098612               0.000000
# 2                      0.000000        0.000000               0.693147
# ...

# %%
#Para mostrar la matriz de correlación entre variables.
plt.figure(figsize = (20, 20))
corr_matrix = df.iloc[:, :12].corr()
sns.heatmap(corr_matrix, annot = True, cbar = False)
# Out:
# <Axes: >

# %%
#se suman los valores nulos
df.isna().sum()
# Out:
# Session_Activity_Count       0
# No_Items_Added_InCart        0
# No_Items_Removed_FromCart    0
# No_Cart_Viewed               0
# No_Checkout_Confirmed        0
# No_Checkout_Initiated        0
# No_Cart_Items_Viewed         0
# No_Customer_Login            0
# No_Page_Viewed               0
# Is_Product_Details_viewed    0
# Customer_Segment_Type        0
# Cart_Abandoned               0
# dtype: int64

# %%
#se toma una muestra de 10 valores aleatorios
df.sample(10)
# Out:
#       Session_Activity_Count  No_Items_Added_InCart  \
# 1009                1.791759               0.693147
# 3158                2.302585               0.000000
# 2044                2.484907               1.791759
# 2217                2.564949               1.386294
# 2248                1.098612               0.000000
# 3823                1.609438               0.000000
# 2689                3.583519               1.791759
# 1606                2.890372               0.000000
# 1293                1.386294               0.693147
# 2457                1.609438               0.693147
#
#       No_Items_Removed_FromCart  No_Cart_Viewed  No_Checkout_Confirmed  \
# 1009                   0.000000        0.693147               0.000000
# 3158                   0.000000        0.000000               0.000000
# 2044                   0.693147        0.693147               0.000000
# 2217                   0.000000        0.000000               1.098612
# ...

# %%
#imprimimos la forma del DF
print(df.shape)
# Out:
# (4284, 12)

# %%
#Observamos los tipos de variables
df.dtypes
# Out:
# Session_Activity_Count       float64
# No_Items_Added_InCart        float64
# No_Items_Removed_FromCart    float64
# No_Cart_Viewed               float64
# No_Checkout_Confirmed        float64
# No_Checkout_Initiated        float64
# No_Cart_Items_Viewed         float64
# No_Customer_Login            float64
# No_Page_Viewed               float64
# Is_Product_Details_viewed      int64
# Customer_Segment_Type          int64
# Cart_Abandoned                 int64
# dtype: object

# %%
#generamos estadistica descriptiva del DF
df.describe()
# Out:
#        Session_Activity_Count  No_Items_Added_InCart  \
# count             4284.000000            4284.000000
# mean                 2.424419               1.112076
# std                  0.707224               0.835685
# min                  0.000000               0.000000
# 25%                  1.945910               0.693147
# 50%                  2.397895               1.098612
# 75%                  2.890372               1.791759
# max                  6.079933               5.420535
#
#        No_Items_Removed_FromCart  No_Cart_Viewed  No_Checkout_Confirmed  \
# count                4284.000000     4284.000000            4284.000000
# mean                    0.274241        0.689345               0.119811
# std                     0.632218        0.596769               0.285043
# min                     0.000000        0.000000               0.000000
# 25%                     0.000000        0.000000               0.000000
# ...

# %% [markdown]
# Text(0, 0, 'No_Checkout_Confirmed'),
#   Text(1, 0, 'No_Checkout_Initiated '),
#   Text(2, 0, 'No_Customer_Login'),
#   Text(3, 0, 'Session_Activity_Count'),

# %%
#Separamos en X e y
# seleccionamos las variables en X
X = df[['No_Checkout_Confirmed', 'No_Checkout_Initiated ', 'No_Customer_Login', 'Session_Activity_Count']]

# seleccionamos la variable a predecir y
y = df['Cart_Abandoned']

# %%
X
# Out:
#       No_Checkout_Confirmed  No_Checkout_Initiated   No_Customer_Login  \
# 0                  0.000000                0.000000                0.0
# 1                  0.000000                0.000000                0.0
# 2                  0.693147                0.693147                0.0
# 3                  0.000000                0.000000                0.0
# 4                  0.000000                0.000000                0.0
# ...                     ...                     ...                ...
# 4279               0.000000                0.000000                0.0
# 4280               0.000000                0.000000                0.0
# 4281               0.000000                0.693147                0.0
# 4282               0.000000                0.693147                0.0
# 4283               0.000000                0.693147                0.0
#
#       Session_Activity_Count
# 0                   1.609438
# 1                   3.663562
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 4279    1
# 4280    1
# 4281    1
# 4282    1
# 4283    1
# Name: Cart_Abandoned, Length: 4284, dtype: int64

# %%
#Importamos las librerias necesarias para la creacion del modelo
from sklearn.model_selection import train_test_split

#50% para test y 50% para train
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.50, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
# Equilibrio de datos con SMOTE
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
#Arbol de decision
from sklearn.ensemble import RandomForestClassifier

#Creacion del modelo
random_forest = RandomForestClassifier(n_estimators=10, random_state=00000)

# %%
#Entrenamiento
random_forest.fit(X_train_resampled, y_train_resampled)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
X_train_resampled
# Out:
#       No_Checkout_Confirmed  No_Checkout_Initiated   No_Customer_Login  \
# 0                  0.000000                0.693147           0.000000
# 1                  0.000000                1.098612           0.000000
# 2                  0.000000                0.000000           0.000000
# 3                  0.000000                0.000000           0.000000
# 4                  0.000000                0.000000           0.000000
# ...                     ...                     ...                ...
# 3667               0.693147                0.693147           0.693147
# 3668               0.693147                0.693147           0.000000
# 3669               0.693147                0.693147           0.000000
# 3670               0.693147                0.693147           0.693147
# 3671               0.693147                0.693147           0.000000
#
#       Session_Activity_Count
# 0                   2.197225
# 1                   5.613128
# ...

# %%
y_train_resampled
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3667    0
# 3668    0
# 3669    0
# 3670    0
# 3671    0
# Name: Cart_Abandoned, Length: 3672, dtype: int64

# %%
#Calculo de las predicciones en Train y Test
y_pred_test = random_forest.predict(X_test)
print("Test Set Predictions:", y_pred_test)

y_pred_train = random_forest.predict(X_train_resampled)
print("Train Set Predictions:", y_pred_train)
#y_train_pred = random_forest.predict(X_train_resampled)
#y_test_pred = random_forest.predict(y_train_resampled)
# Out:
# Test Set Predictions: [0 1 1 ... 1 1 0]
# Train Set Predictions: [1 1 1 ... 0 0 0]

# %%
#Calculo de metricas
from sklearn.metrics import accuracy_score

#Calculo el accuracy en Train
train_accuracy = accuracy_score(y_train_resampled, y_pred_train)

#Calculo el accuracy en Test
test_accuracy = accuracy_score(y_test, y_pred_test)

print('El accuracy en train es:', train_accuracy)
print('El accuracy en test es:', test_accuracy)
# Out:
# El accuracy en train es: 0.991557734204793
# El accuracy en test es: 0.9822595704948646

# %%
#Verificamos el feature importances
feature_importances_df = pd.DataFrame(
    {"feature": list(X.columns), "importance": random_forest.feature_importances_}).sort_values("importance", ascending = False)

# Mostrar
feature_importances_df
# Out:
#                   feature  importance
# 0   No_Checkout_Confirmed    0.863455
# 1  No_Checkout_Initiated     0.087822
# 3  Session_Activity_Count    0.033188
# 2       No_Customer_Login    0.015535

# %%
#Evaluamos las variables de mayor importancia para la precision del modelo
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x=feature_importances_df.feature, y=feature_importances_df.importance)
plt.xlabel("Feature Importance Score")
plt.ylabel("Features")
plt.title("Visualizando la importancia de cada Feature")
plt.xticks(rotation=45, horizontalalignment = "right", fontweight="light", fontsize="x-large")
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'No_Checkout_Confirmed'),
#   Text(1, 0, 'No_Checkout_Initiated '),
#   Text(2, 0, 'Session_Activity_Count'),
#   Text(3, 0, 'No_Customer_Login')])

# %%
# Matriz de confusion del RF, para observar cuantas veces se equivoca nuestro modelo
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_test)

print('Matriz de Confusion\n\n', cm)
# Out:
# Matriz de Confusion
#
#  [[ 300   10]
#  [  28 1804]]

# %%
#RF
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       310
#            1       0.99      0.98      0.99      1832
#
#     accuracy                           0.98      2142
#    macro avg       0.95      0.98      0.97      2142
# weighted avg       0.98      0.98      0.98      2142

# %%
import joblib
# Guardar el modelo en un archivo
joblib.dump(random_forest, 'modelo.pkl')
# Out:
# ['modelo.pkl']

# %%
import joblib
# Guardar el modelo en un archivo
joblib.dump(random_forest, 'modelo2.pkl')
# Out:
# ['modelo2.pkl']

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 37.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 6.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.9/315.9 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 967.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
# ...

# %%
#importamos gradio para interface grafica
import gradio as gr

# %%
#Definimos las variables que va a tomar en cuenta nuestro modelo
def predict_customer_segment_type(No_Checkout_Confirmed,No_Checkout_Initiated,No_Customer_Login,Session_Activity_Count):
    x = np.array([No_Checkout_Confirmed,No_Checkout_Initiated,No_Customer_Login,Session_Activity_Count])
    pred = random_forest.predict(x.reshape(1, -1))
    return pred[0]

# %%
#Definimos nuestra variables en etiquetas
No_Checkout_Confirmed = gr.Number(label='No_Checkout_Confirmed')
No_Checkout_Initiated = gr.Number(label='No_Checkout_Initiated ')
No_Customer_Login = gr.Number(label='No_Customer_Login')
Session_Activity_Count = gr.Number(label='Session_Activity_Count')
output = gr.Textbox(label='Cart_Abandoned')

# %%
app = gr.Interface(predict_customer_segment_type, inputs=[No_Checkout_Confirmed,No_Checkout_Initiated,No_Customer_Login,Session_Activity_Count], outputs=output, description= 'This is customer segmented predict')

# %%
df
# Out:
#       Session_Activity_Count  No_Items_Added_InCart  \
# 0                   1.609438               0.693147
# 1                   3.663562               0.000000
# 2                   2.197225               1.791759
# 3                   1.945910               0.000000
# 4                   3.465736               2.708050
# ...                      ...                    ...
# 4279                3.178054               1.791759
# 4280                2.079442               1.098612
# 4281                1.609438               0.693147
# 4282                2.197225               1.386294
# 4283                3.465736               1.609438
#
#       No_Items_Removed_FromCart  No_Cart_Viewed  No_Checkout_Confirmed  \
# 0                      0.000000        0.000000               0.000000
# 1                      0.000000        1.098612               0.000000
# 2                      0.000000        0.000000               0.693147
# ...

# %%
app.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://aaf6a7fdee194a1559.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      68     try:
# ---> 69         yield
#      70     except Exception as exc:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     232         with map_httpcore_exceptions():
# ...
